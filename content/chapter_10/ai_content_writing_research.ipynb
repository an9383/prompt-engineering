# %%
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.output_parsers import PydanticOutputParser
from langchain_text_splitters import RecursiveCharacterTextSplitter
import os

# %%
# Custom imports:
from content_collection import collect_serp_data_and_extract_text_from_webpages
from custom_summarize_chain import create_all_summaries, DocumentSummary
from expert_interview_chain import InterviewChain

# %% [markdown]
# ## Topic Research:

# %%
# %pip install google-search-results pandas html2text pytest-playwright chromadb nest_asyncio --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# !playwright install

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
# Constant variables:
TOPIC = "Neural networks"
os.environ["SERPAPI_API_KEY"] = "e56bc28e570af704a67cda84ac4595fa540b4f4dc308de389c779da00fd4c4f9"
os.environ["STABILITY_API_KEY"] = ""

# %%
# Extract content from webpages into LangChain documents:
text_documents = await collect_serp_data_and_extract_text_from_webpages(topic=TOPIC)
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
# LLM, text splitter + parser:
llm = ChatOpenAI(temperature=0)
text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    chunk_size=1500, chunk_overlap=400
)
parser = PydanticOutputParser(pydantic_object=DocumentSummary)

# %%
summaries = await create_all_summaries(text_documents, parser, llm, text_splitter)
# Out:
# d:\WorkSpace\Python\prompt-engineering\content\chapter_10\custom_summarize_chain.py:52: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 2.0.0. Use `RunnableSequence, e.g., `prompt | llm`` instead.
#   llm_chain = LLMChain(llm=llm, prompt=PromptTemplate.from_template(prompt_template))
# d:\WorkSpace\Python\prompt-engineering\content\chapter_10\custom_summarize_chain.py:58: LangChainDeprecationWarning: The class `StuffDocumentsChain` was deprecated in LangChain 0.2.13 and will be removed in 2.0.0. Use `langchain.agents.create_agent` instead. Build new RAG flows with `create_agent` and a retrieval tool. See https://docs.langchain.com/oss/python/langchain/rag
#   stuff_chain = StuffDocumentsChain(
# Summarizing the data!
# Summarizing the data!
# Summarizing the data!
# Time taken: 2.7026093006134033
# Finished summarizing the data!
# ---
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File d:\WorkSpace\Python\prompt-engineering\content\chapter_10\chap10\lib\site-packages\langchain_core\output_parsers\json.py:88, in JsonOutputParser.parse_result(self, result, partial)
#      87 try:
# ---> 88     return parse_json_markdown(text)
#      89 except JSONDecodeError as e:
#
# File d:\WorkSpace\Python\prompt-engineering\content\chapter_10\chap10\lib\site-packages\langchain_core\utils\json.py:163, in parse_json_markdown(json_string, parser)
#     162     json_str = json_string if match is None else match.group(2)
# --> 163 return _parse_json(json_str, parser=parser)
#
# File d:\WorkSpace\Python\prompt-engineering\content\chapter_10\chap10\lib\site-packages\langchain_core\utils\json.py:191, in _parse_json(json_str, parser)
#     190 # Parse the JSON string into a Python dictionary
# --> 191 return parser(json_str)
#
# File d:\WorkSpace\Python\prompt-engineering\content\chapter_10\chap10\lib\site-packages\langchain_core\utils\json.py:136, in parse_partial_json(s, strict)
#     133 # If we got here, we ran out of characters to remove
#     134 # and still couldn't parse the string as JSON, so return the parse error
#     135 # for the original string.
# --> 136 return json.loads(s, strict=strict)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\json\__init__.py:359, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     358     kw['parse_constant'] = parse_constant
# --> 359 return cls(**kw).decode(s)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# The above exception was the direct cause of the following exception:
#
# OutputParserException                     Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 summaries = await create_all_summaries(text_documents, parser, llm, text_splitter)
#
# File d:\WorkSpace\Python\prompt-engineering\content\chapter_10\custom_summarize_chain.py:88, in create_all_summaries(text_documents, parser, llm, text_splitter)
#      82 tasks = [
#      83     create_summary_from_text(document, parser, llm, text_splitter)
#      84     for document in text_documents
#      85 ]
#      87 # Execute the tasks concurrently and gather all the results:
# ---> 88 results = await asyncio.gather(*tasks)
#      90 # Filter out None values
#      91 summaries = [summary for summary in results if summary is not None]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\asyncio\tasks.py:304, in Task.__wakeup(self, future)
#     302 def __wakeup(self, future):
#     303     try:
# --> 304         future.result()
#     305     except BaseException as exc:
#     306         # This may also be a cancellation.
#     307         self.__step(exc)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\asyncio\tasks.py:232, in Task.__step(***failed resolving arguments***)
#     228 try:
#     229     if exc is None:
#     230         # We use the `send` method directly, because coroutines
#     231         # don't have `__iter__` and `__next__` methods.
# --> 232         result = coro.send(None)
#     233     else:
#     234         result = coro.throw(exc)
#
# File d:\WorkSpace\Python\prompt-engineering\content\chapter_10\custom_summarize_chain.py:70, in create_summary_from_text(document, parser, llm, text_splitter)
#      68 print(f"Time taken: {time.time() - start_time}")
#      69 print("Finished summarizing the data!\n---" "")
# ---> 70 document_summary = parser.parse(summary_result["output_text"])
#      71 document_summary.metadata = document.metadata
#      72 return document_summary
#
# File d:\WorkSpace\Python\prompt-engineering\content\chapter_10\chap10\lib\site-packages\langchain_core\output_parsers\pydantic.py:91, in PydanticOutputParser.parse(self, text)
#      82 def parse(self, text: str) -> TBaseModel:
#      83     """Parse the output of an LLM call to a Pydantic object.
#      84
#      85     Args:
#    (...)
#      89         The parsed Pydantic object.
#      90     """
# ---> 91     return self.parse_result([Generation(text=text)])
#
# File d:\WorkSpace\Python\prompt-engineering\content\chapter_10\chap10\lib\site-packages\langchain_core\output_parsers\pydantic.py:75, in PydanticOutputParser.parse_result(self, result, partial)
#      58 """Parse the result of an LLM call to a Pydantic object.
#      59
#      60 Args:
#    (...)
#      72     The parsed Pydantic object.
#      73 """
#      74 try:
# ---> 75     json_object = super().parse_result(result)
#      76     return self._parse_obj(json_object)
#      77 except OutputParserException:
#
# File d:\WorkSpace\Python\prompt-engineering\content\chapter_10\chap10\lib\site-packages\langchain_core\output_parsers\json.py:91, in JsonOutputParser.parse_result(self, result, partial)
#      89 except JSONDecodeError as e:
#      90     msg = f"Invalid json output: {text}"
# ---> 91     raise OutputParserException(msg, llm_output=text) from e
#
# OutputParserException: Invalid json output: Key Points:
# - IBM offers various support services including self-service tools for resolving product issues, a community for sharing knowledge, access to digital resources for developers, comprehensive technical documentation, and access to subject matter experts on the IBM Cloud platform.
# - IBM also provides implementation services, training opportunities, and Technology Lifecycle Services for data center management.
# - The Think 2026 event focuses on the scale advantage with AI and hybrid cloud, with keynotes discussing topics like neural networks and machine learning.
#
# Expert Opinions:
# - The support services provided by IBM aim to drive better business outcomes and enhance the support experience for customers.
# - The Think 2026 event highlights the importance of AI and hybrid cloud in achieving scale advantage in the future.
#
# Concise Summary:
# IBM offers a range of support services, including self-service tools, community collaboration, developer resources, technical documentation, and access to experts. The Think 2026 event focuses on AI and hybrid cloud technologies, with discussions on neural networks and machine learning.
# For troubleshooting, visit: https://docs.langchain.com/oss/python/langchain/errors/OUTPUT_PARSING_FAILURE
# Time taken: 3.050956964492798
# Finished summarizing the data!
# ---
# Time taken: 3.8877928256988525
# Finished summarizing the data!
# ---

# %% [markdown]
# ---
#
# ## Expert Interview Questions:

# %%
interview_chain = InterviewChain(topic=TOPIC, document_summaries=summaries)
interview_questions = interview_chain()

# %% [markdown]
# ----------------------------------------

# %% [markdown]
# ## Answer The Interview Questions:

# %%
for question in interview_questions.questions:
    print(f"Answer the following question: {question.question}\n", flush=True)
    answer = input(f"Answer the following question: {question.question}\n")
    print('------------------------------------------')
    question.answer = answer
# Out:
# Answer the following question: Can you explain the historical foundations of neural networks in machine learning and highlight key developments?
#
# ------------------------------------------
# Answer the following question: What are the different learning paradigms associated with neural networks, and how do they impact the training process?
#
# ------------------------------------------
# Answer the following question: Could you provide insights on the theoretical properties of neural networks, such as computational power and generalization?
#
# ------------------------------------------
# Answer the following question: In what areas or applications are neural networks commonly used, and what makes them particularly effective in those domains?
#
# ------------------------------------------
# Answer the following question: What are some of the major challenges and issues faced in the field of neural networks, especially in terms of training and practical implementation?
#
# ------------------------------------------

# %% [markdown]
# ---
#
# ## General Article Outline:

# %%
from article_outline_generation import BlogOutlineGenerator

blog_outline_generator = BlogOutlineGenerator(topic=TOPIC, questions_and_answers=[item.dict()  
                                                                                  for item in interview_questions.questions ] )
questions_and_answers = blog_outline_generator.questions_and_answers
outline_result = blog_outline_generator.generate_outline(summaries)
# Out:
# Generating the outline...
# ---
# Finished generating the outline!
# ---

# %% [markdown]
# ---
#
# ## Article Text Generation:

# %%
from article_generation import ContentGenerator

content_gen = ContentGenerator(topic=TOPIC, outline=outline_result, questions_and_answers=questions_and_answers)

# Vectorize and store the original webpages:
content_gen.split_and_vectorize_documents(text_documents)

# Create the blog post (this may take several minutes to run, so please be patient):
blog_post = content_gen.generate_blog_post()
# Out:
# Generating the blog post...
# ---
# Finished generating the blog post!
# ---

# %%
blog_post
# Out:
# ["## Historical Foundations of Neural Networks\n\nNeural networks have a rich history dating back to significant developments in the field of machine learning. Here's a concise overview of the historical foundations of neural networks:\n\n1. **1960s and 1970s**: \n   - Fundamental research in neural networks took place during this period.\n   - The first operational deep learning algorithm, the group method of data handling, was introduced in 1965 by Alexey Ivakhnenko and Valentin Lapa in the Soviet Union. This method paved the way for training arbitrarily deep neural networks.\n   - In 1971, a paper described a deep network with eight layers trained through regression analysis. This marked a significant advancement in training deep neural networks.\n   - The introduction of the ReLU (rectified linear unit) activation function by Kunihiko Fukushima in 1969 was a crucial development that remains a fundamental component in neural network architectures.\n\n2. **Mathematical Foundations**: \n   - The historical origins of neural networks can be traced back to statistical methods developed over two centuries ago.\n   - The simplest form of feedforward neural network, a linear network, utilizes linear activation functions and weights to calculate outputs. This technique, akin to linear regression, was pioneered by Legendre and Gauss for predicting planetary movement.\n\n3. **Perceptrons**:\n   - While computers are traditionally based on John von Neumann's model of explicit instruction execution, neural networks emerged from the desire to model information processing in biological systems through connectionism.\n   - Unlike the von Neumann architecture, neural networks embrace a connectionist computing approach that integrates memory and processing without clear segregation.\n\nNeural networks have evolved significantly since their inception, with key milestones contributing to their current state as powerful tools for information processing and pattern recognition.",
#  "## Learning Paradigms in Neural Networks\n\nIn the realm of neural networks, various learning paradigms play a crucial role in shaping how these systems acquire knowledge and adjust their parameters. Let's delve into the different learning paradigms associated with neural networks:\n\n1. **Supervised Learning**:\n   - Supervised learning is a prevalent paradigm where the neural network is trained on labeled data, allowing it to learn mappings from inputs to outputs.\n   - This paradigm involves providing the network with input-output pairs and adjusting its weights and biases to minimize errors between predicted and actual outputs.\n   - Supervised learning is commonly used in tasks such as image classification, speech recognition, and natural language processing.\n\n2. **Unsupervised Learning**:\n   - Unsupervised learning involves training neural networks on unlabeled data, prompting the system to discover patterns or structure within the data.\n   - Unlike supervised learning, the network must infer the underlying structure of the data without explicit labels.\n   - Clustering, dimensionality reduction, and anomaly detection are examples of tasks where unsupervised learning is applied.\n\n3. **Reinforcement Learning**:\n   - In reinforcement learning, neural networks learn through trial and error by interacting with an environment and receiving feedback in the form of rewards or penalties.\n   - The network adjusts its actions based on the received feedback to maximize cumulative rewards over time.\n   - Reinforcement learning is widely used in robotics, game playing, and autonomous systems.\n\n4. **Semi-Supervised Learning**:\n   - Semi-supervised learning combines aspects of both supervised and unsupervised learning paradigms.\n   - This approach leverages a small amount of labeled data alongside a larger set of unlabeled data to improve learning accuracy.\n   - Semi-supervised learning is beneficial when labeled data is scarce or expensive to obtain.\n\nThe choice of learning paradigm significantly influences how neural networks are trained and the types of tasks they excel in. Each paradigm offers unique advantages and challenges, contributing to the versatility and adaptability of neural network systems.",
#  "## Theoretical Properties of Neural Networks\n\nWhen exploring the theoretical properties of neural networks, several key aspects come to light that underpin their computational power and capabilities. Let's dive into these important properties:\n\n- **Computational Power**:\n  - The multilayer perceptron stands out as a universal function approximator, validated by the universal approximation theorem. This foundational theorem establishes the ability of neural networks to approximate any continuous function given appropriate conditions.\n  - While the multilayer perceptron demonstrates universality, the theorem does not specify the exact requirements in terms of neurons, network topology, weights, or learning parameters. This flexibility in design allows for diverse implementations tailored to specific tasks.\n  - Beyond the multilayer perceptron, recurrent architectures equipped with rational-valued weights exhibit the computational prowess equivalent to a universal Turing machine. This insight showcases the transformative capabilities of neural networks in computational tasks.\n  - Notably, the utilization of irrational weight values can elevate neural networks to super-Turing power, indicating a realm of computation beyond traditional boundaries.\n\n- **Capacity**:\n  - A critical property of neural networks is their capacity to model various functions. This capacity reflects the network's ability to store information and handle complexity effectively.\n  - Information capacity and the VC dimension serve as metrics for assessing the network's modeling potential under different scenarios.\n  - The VC dimension, derived from measure theory principles, provides insights into the network's maximum capacity under optimal conditions and specific input data structures.\n  - Understanding the capacity of a network sheds light on its ability to model functions across diverse datasets and input formats.\n\n- **Convergence**:\n  - Models in neural networks may encounter challenges related to convergence towards a singular solution. Local minima can hinder convergence, leading to suboptimal outcomes.\n  - The optimization methods employed during training play a crucial role in navigating potential obstacles like local minima and saddle points.\n  - Additionally, the convergence of models may vary based on the scale of data and model parameters, influencing the efficiency and effectiveness of training processes.\n\nBy delving into the theoretical properties of neural networks, we gain a deeper understanding of their computational foundations, modeling capabilities, and convergence dynamics, essential for harnessing the full potential of these powerful information processing systems.",
#  '## Applications of Neural Networks\n\nNeural networks have gained widespread adoption across various fields due to their ability to model and reproduce nonlinear processes effectively. Here are some key areas where neural networks are applied:\n\n1. **Image Processing**:\n   - Neural networks play a vital role in image processing tasks such as object recognition, segmentation, and image enhancement.\n   - Convolutional Neural Networks (CNNs) have revolutionized image classification and analysis by learning hierarchical features directly from pixel values.\n\n2. **Speech Recognition**:\n   - Neural networks are at the core of speech recognition systems, enabling the conversion of spoken language into text.\n   - Recurrent Neural Networks (RNNs) and Long Short-Term Memory (LSTM) networks are commonly used for modeling sequential data in speech processing.\n\n3. **Natural Language Processing (NLP)**:\n   - In NLP applications, neural networks excel in tasks like language translation, sentiment analysis, and text generation.\n   - Transformer models, like BERT and GPT, have significantly advanced the state-of-the-art in NLP tasks by capturing long-range dependencies in text data.\n\n4. **Finance**:\n   - Neural networks have found extensive applications in finance for tasks like stock price prediction, risk assessment, and algorithmic trading.\n   - Financial institutions leverage neural networks to analyze market trends, sentiment analysis from news sources, and customer behavior prediction.\n\n5. **Medicine**:\n   - In the field of medicine, neural networks aid in medical image analysis, disease diagnosis, and personalized treatment planning.\n   - They enhance diagnostic accuracy in medical imaging and expedite drug discovery processes by predicting efficacy and safety of potential candidates.\n\n6. **Robotics**:\n   - Neural networks are pivotal in robotics for tasks such as path planning, object recognition, and control of robotic manipulators.\n   - They enable robots to perceive and interact with their environment effectively, leading to advancements in autonomous systems.\n\n7. **Cybersecurity**:\n   - Neural networks are instrumental in cybersecurity for anomaly detection, malware classification, and intrusion detection.\n   - By learning patterns of normal system behavior, neural networks can identify deviations indicative of potential security threats.\n\n8. **Content Creation**:\n   - Neural networks are increasingly used in content creation tasks like generating text, images, and music.\n   - Generative models like Variational Autoencoders (VAEs) and Generative Adversarial Networks (GANs) are employed for creative content generation.\n\nIn each of these domains, neural networks demonstrate their versatility and effectiveness by tackling complex tasks that require pattern recognition, data processing, and decision-making capabilities. Their adaptability and robustness make them indispensable tools in modern applications.',
#  "## Challenges and Issues in Neural Networks\n\nNeural networks have seen remarkable advancements and widespread adoption in various fields, but they also face significant challenges and issues that impact their development and deployment. Let's delve into some of the key challenges and issues encountered in the field of neural networks:\n\n- **Training Complexity**:\n  - Neural networks require extensive training datasets to achieve optimal performance, posing a challenge in acquiring and labeling large volumes of data.\n  - Training commercial models like GPT, Grok, and Gemini can necessitate significant computational resources, including hundreds of thousands of computers and millions of dollars, emphasizing the high cost of training high-performing networks.\n\n- **Theoretical Understanding**:\n  - While neural networks are touted for embodying new and powerful principles for information processing, they fundamentally rely on statistical methods that have been long-developed.\n  - Bridging the gap between theoretical properties and practical implementations remains a challenge, requiring continuous research to enhance our understanding of neural network behavior.\n\n- **Hardware Requirements**:\n  - Neural networks demand substantial computing resources for training, with commercial transformers requiring data centers consuming hundreds of megawatts of power.\n  - The disparity between the energy efficiency of biological neural processing and the resource-intensive training of artificial neural networks underscores the challenges in efficient hardware utilization.\n\n- **Concept Drift**:\n  - Concept drift or non-stationarity in input data presents a significant challenge for neural networks, as shifts in data properties over time can lead to reduced predictive accuracy and biased decisions.\n  - Monitoring neural networks for concept drift and implementing strategies to address data changes during deployment are essential to maintain model performance and reliability.\n\n- **Performance Optimization**:\n  - Enhancing the performance and efficiency of neural networks necessitates continuous optimization of model architectures, training algorithms, and hyperparameters.\n  - Balancing model complexity, interpretability, and computational efficiency poses a challenge in developing neural network systems that are both accurate and scalable.\n\nAddressing these challenges and issues in neural networks requires interdisciplinary collaboration, innovative solutions in algorithms and hardware design, and a deeper understanding of the theoretical foundations of neural network behavior. By tackling these hurdles, the field of neural networks can advance further and unlock new possibilities for intelligent information processing."]

# %% [markdown]
# -----
#
# ## Image Creation:

# %%
from image_generation_chain import create_image
image = create_image(outline_result.title)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[40], line 2
#       1 from image_generation_chain import create_image
# ----> 2 image = create_image(outline_result.title)
#
# File d:\WorkSpace\Python\prompt-engineering\content\chapter_10\image_generation_chain.py:52, in create_image(title)
#      29 response = requests.post(
#      30     f"{api_host}/v1/generation/{engine_id}/text-to-image",
#      31     timeout=60,
#    (...)
#      48     },
#      49 )
#      51 if response.status_code != 200:
# ---> 52     raise Exception("Non-200 response: " + str(response.text))
#      54 data = response.json()
#      55 image_paths = []
#
# Exception: Non-200 response: {"id":"a8692cac384d15134890c0050d371d40","message":"Incorrect API key provided: Bearer. You can find your API key at https://stability.ai.","name":"unauthorized"}

# %%
print(f"The image is ready! The filepath is {image[0]}")
# Out:
# The image is ready! The filepath is ab94a65.png
