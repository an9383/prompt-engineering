# %% [markdown]
# ## Token Usage

# %%
import asyncio
from langchain.callbacks import get_openai_callback
from langchain_core.messages import SystemMessage
from langchain_openai.chat_models import ChatOpenAI

# %%
model = ChatOpenAI(api_key="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")

# %%
with get_openai_callback() as cb:
    model.invoke([SystemMessage(content="My name is James")])
total_tokens = cb.total_tokens
print(total_tokens)
assert total_tokens > 0
# Out:
# 21

# %%
with get_openai_callback() as cb:
    model.invoke([SystemMessage(content="My name is James")])
    model.invoke([SystemMessage(content="My name is James")])
assert cb.total_tokens == total_tokens * 2

# %%
# Async callbacks:
with get_openai_callback() as cb:
    await asyncio.gather(
        model.agenerate(
            [
                [SystemMessage(content="Is the meaning of life 42?")],
                [SystemMessage(content="Is the meaning of life 42?")],
            ],
        )
    )
print(cb.__dict__)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 # Async callbacks:
#       2 with get_openai_callback() as cb:
# ----> 3     await asyncio.gather(
#       4         model.agenerate(
#       5             [
#       6                 [SystemMessage(content="Is the meaning of life 42?")],
#       7                 [SystemMessage(content="Is the meaning of life 42?")],
#       8             ],
#       9         )
#      10     )
#      11 print(cb.__dict__)
#
# File e:\WorkSpace\Python\prompt-engineering\chap6\lib\site-packages\langchain_core\language_models\chat_models.py:535, in BaseChatModel.agenerate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     530     raise exceptions[0]
#     531 flattened_outputs = [
#     532     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item, union-attr]
#     533     for res in results
#     534 ]
# --> 535 llm_output = self._combine_llm_outputs([res.llm_output for res in results])  # type: ignore[union-attr]
#     536 generations = [res.generations for res in results]  # type: ignore[union-attr]
#     537 output = LLMResult(generations=generations, llm_output=llm_output)  # type: ignore[arg-type]
#
# File e:\WorkSpace\Python\prompt-engineering\chap6\lib\site-packages\langchain_openai\chat_models\base.py:485, in ChatOpenAI._combine_llm_outputs(self, llm_outputs)
#     483 for k, v in token_usage.items():
#     484     if k in overall_token_usage:
# --> 485         overall_token_usage[k] += v
#     486     else:
#     487         overall_token_usage[k] = v
#
# TypeError: unsupported operand type(s) for +=: 'dict' and 'dict'
