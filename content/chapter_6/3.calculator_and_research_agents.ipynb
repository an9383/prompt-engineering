# %%
# Demonstrating how to use langchain.debug to print out the intermediate results with stack traces:
import langchain
langchain.debug = True

# %%
# Import necessary modules and functions from the langchain package:
from langchain.chains import (
    LLMMathChain,
)
from langchain import hub
from langchain.agents import create_openai_functions_agent, Tool, AgentExecutor
from langchain_openai.chat_models import ChatOpenAI
# Out:
# e:\WorkSpace\Python\prompt-engineering\chap6\lib\site-packages\langchain_openai\chat_models\__init__.py:1: LangChainDeprecationWarning: As of langchain-core 0.3.0, LangChain uses pydantic v2 internally. The langchain_core.pydantic_v1 module was a compatibility shim for pydantic v1, and should no longer be used. Please update the code to import from Pydantic directly.
#
# For example, replace imports like: `from langchain_core.pydantic_v1 import BaseModel`
# with: `from pydantic import BaseModel`
# or the v1 compatibility namespace if you are working in a code base that has not been fully upgraded to pydantic 2 yet. 	from pydantic.v1 import BaseModel
#
#   from langchain_openai.chat_models.azure import AzureChatOpenAI
# e:\WorkSpace\Python\prompt-engineering\chap6\lib\site-packages\pydantic\_internal\_config.py:386: UserWarning: Valid config keys have changed in V2:
# * 'allow_population_by_field_name' has been renamed to 'validate_by_name'
#   warnings.warn(message, UserWarning)
# ---------------------------------------------------------------------------
# PydanticUserError                         Traceback (most recent call last)
# Cell In[1], line 7
#       5 from langchain import hub
#       6 from langchain.agents import create_openai_functions_agent, Tool, AgentExecutor
# ----> 7 from langchain_openai.chat_models import ChatOpenAI
#
# File e:\WorkSpace\Python\prompt-engineering\chap6\lib\site-packages\langchain_openai\__init__.py:1
# ----> 1 from langchain_openai.chat_models import (
#       2     AzureChatOpenAI,
#       3     ChatOpenAI,
#       4 )
#       5 from langchain_openai.embeddings import (
#       6     AzureOpenAIEmbeddings,
#       7     OpenAIEmbeddings,
#       8 )
#       9 from langchain_openai.llms import AzureOpenAI, OpenAI
#
# File e:\WorkSpace\Python\prompt-engineering\chap6\lib\site-packages\langchain_openai\chat_models\__init__.py:1
# ----> 1 from langchain_openai.chat_models.azure import AzureChatOpenAI
#       2 from langchain_openai.chat_models.base import ChatOpenAI
#       4 __all__ = [
#       5     "ChatOpenAI",
#       6     "AzureChatOpenAI",
#       7 ]
#
# File e:\WorkSpace\Python\prompt-engineering\chap6\lib\site-packages\langchain_openai\chat_models\azure.py:13
#      10 from langchain_core.pydantic_v1 import Field, SecretStr, root_validator
#      11 from langchain_core.utils import convert_to_secret_str, get_from_dict_or_env
# ---> 13 from langchain_openai.chat_models.base import ChatOpenAI
#      15 logger = logging.getLogger(__name__)
#      18 class AzureChatOpenAI(ChatOpenAI):
#
# File e:\WorkSpace\Python\prompt-engineering\chap6\lib\site-packages\langchain_openai\chat_models\base.py:275
#     271     parsed: Optional[_DictOrPydantic]
#     272     parsing_error: Optional[BaseException]
# --> 275 class ChatOpenAI(BaseChatModel):
#     276     """`OpenAI` Chat large language models API.
#     277
#     278     To use, you should have the environment variable ``OPENAI_API_KEY``
#    (...)
#     289             model = ChatOpenAI(model="gpt-3.5-turbo")
#     290     """
#     292     @property
#     293     def lc_secrets(self) -> Dict[str, str]:
#
# File e:\WorkSpace\Python\prompt-engineering\chap6\lib\site-packages\pydantic\_internal\_model_construction.py:256, in ModelMetaclass.__new__(mcs, cls_name, bases, namespace, __pydantic_generic_metadata__, __pydantic_reset_parent_namespace__, _create_model_module, **kwargs)
#     252     set_model_mocks(cls)
#     253 else:
#     254     # Any operation that requires accessing the field infos instances should be put inside
#     255     # `complete_model_class()`:
# --> 256     complete_model_class(
#     257         cls,
#     258         config_wrapper,
#     259         ns_resolver,
#     260         raise_errors=False,
#     261         create_model_module=_create_model_module,
#     262     )
#     264 if config_wrapper.frozen and '__hash__' not in namespace:
#     265     set_default_hash_func(cls, bases)
#
# File e:\WorkSpace\Python\prompt-engineering\chap6\lib\site-packages\pydantic\_internal\_model_construction.py:667, in complete_model_class(cls, config_wrapper, ns_resolver, raise_errors, call_on_complete_hook, create_model_module, is_force_rebuild)
#     660 gen_schema = GenerateSchema(
#     661     config_wrapper,
#     662     ns_resolver,
#     663     typevars_map,
#     664 )
#     666 try:
# --> 667     schema = gen_schema.generate_schema(cls)
#     668 except PydanticUndefinedAnnotation as e:
#     669     if raise_errors:
#
# File e:\WorkSpace\Python\prompt-engineering\chap6\lib\site-packages\pydantic\_internal\_generate_schema.py:744, in GenerateSchema.generate_schema(self, obj)
#     741 schema = self._generate_schema_from_get_schema_method(obj, obj)
#     743 if schema is None:
# --> 744     schema = self._generate_schema_inner(obj)
#     746 metadata_js_function = _extract_get_pydantic_json_schema(obj)
#     747 if metadata_js_function is not None:
#
# File e:\WorkSpace\Python\prompt-engineering\chap6\lib\site-packages\pydantic\_internal\_generate_schema.py:1028, in GenerateSchema._generate_schema_inner(self, obj)
#    1026 if lenient_issubclass(obj, BaseModel):
#    1027     with self.model_type_stack.push(obj):
# -> 1028         return self._model_schema(obj)
#    1030 if isinstance(obj, PydanticRecursiveRef):
#    1031     return core_schema.definition_reference_schema(schema_ref=obj.type_ref)
#
# File e:\WorkSpace\Python\prompt-engineering\chap6\lib\site-packages\pydantic\_internal\_generate_schema.py:858, in GenerateSchema._model_schema(self, cls)
#     846     model_schema = core_schema.model_schema(
#     847         cls,
#     848         inner_schema,
#    (...)
#     854         ref=model_ref,
#     855     )
#     856 else:
#     857     fields_schema: core_schema.CoreSchema = core_schema.model_fields_schema(
# --> 858         {k: self._generate_md_field_schema(k, v, decorators) for k, v in fields.items()},
#     859         computed_fields=[
#     860             self._computed_field_schema(d, decorators.field_serializers)
#     861             for d in computed_fields.values()
#     862         ],
#     863         extras_schema=extras_schema,
#     864         extras_keys_schema=extras_keys_schema,
#     865         model_name=cls.__name__,
#     866     )
#     867     inner_schema = apply_validators(fields_schema, decorators.root_validators.values())
#     868     inner_schema = apply_model_validators(inner_schema, model_validators, 'inner')
#
# File e:\WorkSpace\Python\prompt-engineering\chap6\lib\site-packages\pydantic\_internal\_generate_schema.py:858, in <dictcomp>(.0)
#     846     model_schema = core_schema.model_schema(
#     847         cls,
#     848         inner_schema,
#    (...)
#     854         ref=model_ref,
#     855     )
#     856 else:
#     857     fields_schema: core_schema.CoreSchema = core_schema.model_fields_schema(
# --> 858         {k: self._generate_md_field_schema(k, v, decorators) for k, v in fields.items()},
#     859         computed_fields=[
#     860             self._computed_field_schema(d, decorators.field_serializers)
#     861             for d in computed_fields.values()
#     862         ],
#     863         extras_schema=extras_schema,
#     864         extras_keys_schema=extras_keys_schema,
#     865         model_name=cls.__name__,
#     866     )
#     867     inner_schema = apply_validators(fields_schema, decorators.root_validators.values())
#     868     inner_schema = apply_model_validators(inner_schema, model_validators, 'inner')
#
# File e:\WorkSpace\Python\prompt-engineering\chap6\lib\site-packages\pydantic\_internal\_generate_schema.py:1235, in GenerateSchema._generate_md_field_schema(self, name, field_info, decorators)
#    1228 def _generate_md_field_schema(
#    1229     self,
#    1230     name: str,
#    1231     field_info: FieldInfo,
#    1232     decorators: DecoratorInfos,
#    1233 ) -> core_schema.ModelField:
#    1234     """Prepare a ModelField to represent a model field."""
# -> 1235     schema, metadata = self._common_field_schema(name, field_info, decorators)
#    1236     return core_schema.model_field(
#    1237         schema,
#    1238         serialization_exclude=field_info.exclude,
#    (...)
#    1243         metadata=metadata,
#    1244     )
#
# File e:\WorkSpace\Python\prompt-engineering\chap6\lib\site-packages\pydantic\_internal\_generate_schema.py:1289, in GenerateSchema._common_field_schema(self, name, field_info, decorators)
#    1285         schema = self._apply_annotations(
#    1286             source_type, annotations + validators_from_decorators, transform_inner_schema=set_discriminator
#    1287         )
#    1288     else:
# -> 1289         schema = self._apply_annotations(
#    1290             source_type,
#    1291             annotations + validators_from_decorators,
#    1292         )
#    1294 # This V1 compatibility shim should eventually be removed
#    1295 # push down any `each_item=True` validators
#    1296 # note that this won't work for any Annotated types that get wrapped by a function validator
#    1297 # but that's okay because that didn't exist in V1
#    1298 this_field_validators = filter_field_decorator_info_by_field(decorators.validators.values(), name)
#
# File e:\WorkSpace\Python\prompt-engineering\chap6\lib\site-packages\pydantic\_internal\_generate_schema.py:2242, in GenerateSchema._apply_annotations(self, source_type, annotations, transform_inner_schema, check_unsupported_field_info_attributes)
#    2234         continue
#    2235     get_inner_schema = self._get_wrapped_inner_schema(
#    2236         get_inner_schema,
#    2237         annotation,
#    2238         pydantic_js_annotation_functions,
#    2239         check_unsupported_field_info_attributes=check_unsupported_field_info_attributes,
#    2240     )
# -> 2242 schema = get_inner_schema(source_type)
#    2243 if pydantic_js_annotation_functions:
#    2244     core_metadata = schema.setdefault('metadata', {})
#
# File e:\WorkSpace\Python\prompt-engineering\chap6\lib\site-packages\pydantic\_internal\_schema_generation_shared.py:83, in CallbackGetCoreSchemaHandler.__call__(self, source_type)
#      82 def __call__(self, source_type: Any, /) -> core_schema.CoreSchema:
# ---> 83     schema = self._handler(source_type)
#      84     if self._ref_mode == 'to-def':
#      85         ref = schema.get('ref')
#
# File e:\WorkSpace\Python\prompt-engineering\chap6\lib\site-packages\pydantic\_internal\_generate_schema.py:2221, in GenerateSchema._apply_annotations.<locals>.inner_handler(obj)
#    2218 schema = self._generate_schema_from_get_schema_method(obj, source_type)
#    2220 if schema is None:
# -> 2221     schema = self._generate_schema_inner(obj)
#    2223 metadata_js_function = _extract_get_pydantic_json_schema(obj)
#    2224 if metadata_js_function is not None:
#
# File e:\WorkSpace\Python\prompt-engineering\chap6\lib\site-packages\pydantic\_internal\_generate_schema.py:1033, in GenerateSchema._generate_schema_inner(self, obj)
#    1030 if isinstance(obj, PydanticRecursiveRef):
#    1031     return core_schema.definition_reference_schema(schema_ref=obj.type_ref)
# -> 1033 return self.match_type(obj)
#
# File e:\WorkSpace\Python\prompt-engineering\chap6\lib\site-packages\pydantic\_internal\_generate_schema.py:1151, in GenerateSchema.match_type(self, obj)
#    1149 origin = get_origin(obj)
#    1150 if origin is not None:
# -> 1151     return self._match_generic_type(obj, origin)
#    1153 if self._arbitrary_types:
#    1154     return self._arbitrary_type_schema(obj)
#
# File e:\WorkSpace\Python\prompt-engineering\chap6\lib\site-packages\pydantic\_internal\_generate_schema.py:1174, in GenerateSchema._match_generic_type(self, obj, origin)
#    1172     return self._type_alias_type_schema(obj)
#    1173 elif is_union_origin(origin):
# -> 1174     return self._union_schema(obj)
#    1175 elif origin in TUPLE_TYPES:
#    1176     return self._tuple_schema(obj)
#
# File e:\WorkSpace\Python\prompt-engineering\chap6\lib\site-packages\pydantic\_internal\_generate_schema.py:1334, in GenerateSchema._union_schema(self, union_type)
#    1332         nullable = True
#    1333     else:
# -> 1334         choices.append(self.generate_schema(arg))
#    1336 if len(choices) == 1:
#    1337     s = choices[0]
#
# File e:\WorkSpace\Python\prompt-engineering\chap6\lib\site-packages\pydantic\_internal\_generate_schema.py:746, in GenerateSchema.generate_schema(self, obj)
#     743 if schema is None:
#     744     schema = self._generate_schema_inner(obj)
# --> 746 metadata_js_function = _extract_get_pydantic_json_schema(obj)
#     747 if metadata_js_function is not None:
#     748     metadata_schema = resolve_original_schema(schema, self.defs)
#
# File e:\WorkSpace\Python\prompt-engineering\chap6\lib\site-packages\pydantic\_internal\_generate_schema.py:2689, in _extract_get_pydantic_json_schema(tp)
#    2687     if not has_custom_v2_modify_js_func:
#    2688         cls_name = getattr(tp, '__name__', None)
# -> 2689         raise PydanticUserError(
#    2690             f'The `__modify_schema__` method is not supported in Pydantic v2. '
#    2691             f'Use `__get_pydantic_json_schema__` instead{f" in class `{cls_name}`" if cls_name else ""}.',
#    2692             code='custom-json-schema',
#    2693         )
#    2695 if (origin := get_origin(tp)) is not None:
#    2696     # Generic aliases proxy attribute access to the origin, *except* dunder attributes,
#    2697     # such as `__get_pydantic_json_schema__`, hence the explicit check.
#    2698     return _extract_get_pydantic_json_schema(origin)
#
# PydanticUserError: The `__modify_schema__` method is not supported in Pydantic v2. Use `__get_pydantic_json_schema__` instead in class `SecretStr`.
#
# For further information visit https://errors.pydantic.dev/2.13/u/custom-json-schema

# %%
# Initialize the ChatOpenAI with temperature set to 0:
model = ChatOpenAI(temperature=0,api_key="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")

# Create a LLMMathChain instance using the ChatOpenAI model:
llm_math_chain = LLMMathChain.from_llm(llm=model, verbose=True)

# Download the prompt from the hub:
prompt = hub.pull("hwchase17/openai-functions-agent")

tools = [
    Tool(
        name="Calculator",
        func=llm_math_chain.run, # run the LLMMathChain
        description="useful for when you need to answer questions about math",
        return_direct=True,
    ),
]

# %%
# Create an agent using the ChatOpenAI model and the tools:
agent = create_openai_functions_agent(llm=model, tools=tools, prompt=prompt)
agent_executor = AgentExecutor(agent=agent, tools=tools, verbose=True)

# %%
result = agent_executor.invoke({"input": "W hat is 5 + 5?"})
print(result)
# Out:
# [chain/start] [1:chain:AgentExecutor] Entering Chain run with input:
# {
#   "input": "W hat is 5 + 5?"
# }
# [chain/start] [1:chain:AgentExecutor > 2:chain:RunnableSequence] Entering Chain run with input:
# {
#   "input": ""
# }
# [chain/start] [1:chain:AgentExecutor > 2:chain:RunnableSequence > 3:chain:RunnableAssign<agent_scratchpad>] Entering Chain run with input:
# {
#   "input": ""
# }
# [chain/start] [1:chain:AgentExecutor > 2:chain:RunnableSequence > 3:chain:RunnableAssign<agent_scratchpad> > 4:chain:RunnableParallel<agent_scratchpad>] Entering Chain run with input:
# {
#   "input": ""
# }
# [chain/start] [1:chain:AgentExecutor > 2:chain:RunnableSequence > 3:chain:RunnableAssign<agent_scratchpad> > 4:chain:RunnableParallel<agent_scratchpad> > 5:chain:RunnableLambda] Entering Chain run with input:
# {
#   "input": ""
# }
# [chain/end] [1:chain:AgentExecutor > 2:chain:RunnableSequence > 3:chain:RunnableAssign<agent_scratchpad> > 4:chain:RunnableParallel<agent_scratchpad> > 5:chain:RunnableLambda] s] Exiting Chain run with output:
# {
#   "output": []
# }
# [chain/end] [1:chain:AgentExecutor > 2:chain:RunnableSequence > 3:chain:RunnableAssign<agent_scratchpad> > 4:chain:RunnableParallel<agent_scratchpad>] s] Exiting Chain run with output:
# {
#   "agent_scratchpad": []
# }
# [chain/end] [1:chain:AgentExecutor > 2:chain:RunnableSequence > 3:chain:RunnableAssign<agent_scratchpad>] s] Exiting Chain run with output:
# {
#   "input": "W hat is 5 + 5?",
#   "intermediate_steps": [],
#   "agent_scratchpad": []
# }
# [chain/start] [1:chain:AgentExecutor > 2:chain:RunnableSequence > 6:prompt:ChatPromptTemplate] Entering Prompt run with input:
# {
#   "input": "W hat is 5 + 5?",
#   "intermediate_steps": [],
#   "agent_scratchpad": []
# }
# [chain/end] [1:chain:AgentExecutor > 2:chain:RunnableSequence > 6:prompt:ChatPromptTemplate] s] Exiting Prompt run with output:
# [outputs]
# [llm/start] [1:chain:AgentExecutor > 2:chain:RunnableSequence > 7:llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are a helpful assistant\nHuman: W hat is 5 + 5?"
#   ]
# }
# [llm/end] [1:chain:AgentExecutor > 2:chain:RunnableSequence > 7:llm:ChatOpenAI] [1.68s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "",
#         "generation_info": {
#           "finish_reason": "function_call"
#         },
#         "type": "ChatGenerationChunk",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessageChunk"
#           ],
#           "kwargs": {
#             "content": "",
#             "example": false,
#             "additional_kwargs": {
#               "function_call": {
#                 "arguments": "{\"__arg1\":\"5 + 5\"}",
#                 "name": "Calculator"
#               }
#             },
#             "tool_call_chunks": [],
#             "response_metadata": {
#               "finish_reason": "function_call"
#             },
#             "id": "run-ac30debb-5f3d-422d-bb90-b8757ea8e215",
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [chain/start] [1:chain:AgentExecutor > 2:chain:RunnableSequence > 8:parser:OpenAIFunctionsAgentOutputParser] Entering Parser run with input:
# [inputs]
# [chain/end] [1:chain:AgentExecutor > 2:chain:RunnableSequence > 8:parser:OpenAIFunctionsAgentOutputParser] s] Exiting Parser run with output:
# [outputs]
# [chain/end] [1:chain:AgentExecutor > 2:chain:RunnableSequence] [1.69s] Exiting Chain run with output:
# [outputs]
# [tool/start] [1:chain:AgentExecutor > 9:tool:Calculator] Entering Tool run with input:
# "5 + 5"
# [chain/start] [1:chain:AgentExecutor > 9:tool:Calculator > 10:chain:LLMMathChain] Entering Chain run with input:
# {
#   "question": "5 + 5"
# }
# [chain/start] [1:chain:AgentExecutor > 9:tool:Calculator > 10:chain:LLMMathChain > 11:chain:LLMChain] Entering Chain run with input:
# {
#   "question": "5 + 5",
#   "stop": [
#     "```output"
#   ]
# }
# [llm/start] [1:chain:AgentExecutor > 9:tool:Calculator > 10:chain:LLMMathChain > 11:chain:LLMChain > 12:llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Translate a math problem into a expression that can be executed using Python's numexpr library. Use the output of running this code to answer the question.\n\nQuestion: ${Question with math problem.}\n```text\n${single line mathematical expression that solves the problem}\n```\n...numexpr.evaluate(text)...\n```output\n${Output of running the code}\n```\nAnswer: ${Answer}\n\nBegin.\n\nQuestion: What is 37593 * 67?\n```text\n37593 * 67\n```\n...numexpr.evaluate(\"37593 * 67\")...\n```output\n2518731\n```\nAnswer: 2518731\n\nQuestion: 37593^(1/5)\n```text\n37593**(1/5)\n```\n...numexpr.evaluate(\"37593**(1/5)\")...\n```output\n8.222831614237718\n```\nAnswer: 8.222831614237718\n\nQuestion: 5 + 5"
#   ]
# }
# [llm/end] [1:chain:AgentExecutor > 9:tool:Calculator > 10:chain:LLMMathChain > 11:chain:LLMChain > 12:llm:ChatOpenAI] [1.42s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "```text\n5 + 5\n```\n...numexpr.evaluate(\"5 + 5\")...\n",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "```text\n5 + 5\n```\n...numexpr.evaluate(\"5 + 5\")...\n",
#             "additional_kwargs": {},
#             "name": null,
#             "id": "run-2161a560-784b-4d88-a63d-6eb62cd22d7a-0",
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "completion_tokens": 23,
#       "prompt_tokens": 204,
#       "total_tokens": 227,
#       "prompt_tokens_details": {
#         "cached_tokens": 0,
#         "audio_tokens": 0
#       },
#       "completion_tokens_details": {
#         "reasoning_tokens": 0,
#         "audio_tokens": 0,
#         "accepted_prediction_tokens": 0,
#         "rejected_prediction_tokens": 0
#       }
#     },
#     "model_name": "gpt-3.5-turbo",
#     "system_fingerprint": null
#   },
#   "run": null
# }
# [chain/end] [1:chain:AgentExecutor > 9:tool:Calculator > 10:chain:LLMMathChain > 11:chain:LLMChain] [1.42s] Exiting Chain run with output:
# {
#   "text": "```text\n5 + 5\n```\n...numexpr.evaluate(\"5 + 5\")...\n"
# }
# [chain/end] [1:chain:AgentExecutor > 9:tool:Calculator > 10:chain:LLMMathChain] [1.42s] Exiting Chain run with output:
# {
#   "answer": "Answer: 10"
# }
# [tool/end] [1:chain:AgentExecutor > 9:tool:Calculator] [1.42s] Exiting Tool run with output:
# "Answer: 10"
# [chain/end] [1:chain:AgentExecutor] [3.11s] Exiting Chain run with output:
# {
#   "output": "Answer: 10"
# }
# {'input': 'W hat is 5 + 5?', 'output': 'Answer: 10'}

# %% [markdown]
# ---
#
# ## 2. Tool Usage:

# %%
def google_search(query: str) -> str:
    return "James Phoenix is 31 years old."

# List of tools that the agent can use.
tools = [
    Tool(
        # The LLMMathChain tool for math calculations.
        func=llm_math_chain.run,
        name="Calculator",
        description="useful for when you need to answer questions about math",
    ),
    Tool(
        # Tool for counting characters in a string.
        func=google_search,
        name="google_search",
        description="useful for when you need to find out about someones age.",
    ),
]

# %%
agent = create_openai_functions_agent(llm=model, tools=tools, prompt=prompt)
agent_executor = AgentExecutor(agent=agent, tools=tools, verbose=True)

# %%
result = agent_executor.invoke(
    {
        "input": """Task: Google search for James Phoenix's age. 
        Then square it."""}
)
print(result)
# Out:
# [chain/start] [1:chain:AgentExecutor] Entering Chain run with input:
# {
#   "input": "Task: Google search for James Phoenix's age. \n        Then square it."
# }
# [chain/start] [1:chain:AgentExecutor > 2:chain:RunnableSequence] Entering Chain run with input:
# {
#   "input": ""
# }
# [chain/start] [1:chain:AgentExecutor > 2:chain:RunnableSequence > 3:chain:RunnableAssign<agent_scratchpad>] Entering Chain run with input:
# {
#   "input": ""
# }
# [chain/start] [1:chain:AgentExecutor > 2:chain:RunnableSequence > 3:chain:RunnableAssign<agent_scratchpad> > 4:chain:RunnableParallel<agent_scratchpad>] Entering Chain run with input:
# {
#   "input": ""
# }
# [chain/start] [1:chain:AgentExecutor > 2:chain:RunnableSequence > 3:chain:RunnableAssign<agent_scratchpad> > 4:chain:RunnableParallel<agent_scratchpad> > 5:chain:RunnableLambda] Entering Chain run with input:
# {
#   "input": ""
# }
# [chain/end] [1:chain:AgentExecutor > 2:chain:RunnableSequence > 3:chain:RunnableAssign<agent_scratchpad> > 4:chain:RunnableParallel<agent_scratchpad> > 5:chain:RunnableLambda] s] Exiting Chain run with output:
# {
#   "output": []
# }
# [chain/end] [1:chain:AgentExecutor > 2:chain:RunnableSequence > 3:chain:RunnableAssign<agent_scratchpad> > 4:chain:RunnableParallel<agent_scratchpad>] s] Exiting Chain run with output:
# {
#   "agent_scratchpad": []
# }
# [chain/end] [1:chain:AgentExecutor > 2:chain:RunnableSequence > 3:chain:RunnableAssign<agent_scratchpad>] s] Exiting Chain run with output:
# {
#   "input": "Task: Google search for James Phoenix's age. \n        Then square it.",
#   "intermediate_steps": [],
#   "agent_scratchpad": []
# }
# [chain/start] [1:chain:AgentExecutor > 2:chain:RunnableSequence > 6:prompt:ChatPromptTemplate] Entering Prompt run with input:
# {
#   "input": "Task: Google search for James Phoenix's age. \n        Then square it.",
#   "intermediate_steps": [],
#   "agent_scratchpad": []
# }
# [chain/end] [1:chain:AgentExecutor > 2:chain:RunnableSequence > 6:prompt:ChatPromptTemplate] s] Exiting Prompt run with output:
# [outputs]
# [llm/start] [1:chain:AgentExecutor > 2:chain:RunnableSequence > 7:llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are a helpful assistant\nHuman: Task: Google search for James Phoenix's age. \n        Then square it."
#   ]
# }
# [llm/end] [1:chain:AgentExecutor > 2:chain:RunnableSequence > 7:llm:ChatOpenAI] s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "",
#         "generation_info": {
#           "finish_reason": "function_call"
#         },
#         "type": "ChatGenerationChunk",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessageChunk"
#           ],
#           "kwargs": {
#             "content": "",
#             "example": false,
#             "additional_kwargs": {
#               "function_call": {
#                 "arguments": "{\"__arg1\":\"James Phoenix age\"}",
#                 "name": "google_search"
#               }
#             },
#             "tool_call_chunks": [],
#             "response_metadata": {
#               "finish_reason": "function_call"
#             },
#             "id": "run-052a1121-5b4c-481f-a6ff-1e4194568aef",
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [chain/start] [1:chain:AgentExecutor > 2:chain:RunnableSequence > 8:parser:OpenAIFunctionsAgentOutputParser] Entering Parser run with input:
# [inputs]
# [chain/end] [1:chain:AgentExecutor > 2:chain:RunnableSequence > 8:parser:OpenAIFunctionsAgentOutputParser] s] Exiting Parser run with output:
# [outputs]
# [chain/end] [1:chain:AgentExecutor > 2:chain:RunnableSequence] s] Exiting Chain run with output:
# [outputs]
# [tool/start] [1:chain:AgentExecutor > 9:tool:google_search] Entering Tool run with input:
# "James Phoenix age"
# [tool/end] [1:chain:AgentExecutor > 9:tool:google_search] s] Exiting Tool run with output:
# "James Phoenix is 31 years old."
# [chain/start] [1:chain:AgentExecutor > 10:chain:RunnableSequence] Entering Chain run with input:
# {
#   "input": ""
# }
# [chain/start] [1:chain:AgentExecutor > 10:chain:RunnableSequence > 11:chain:RunnableAssign<agent_scratchpad>] Entering Chain run with input:
# {
#   "input": ""
# }
# [chain/start] [1:chain:AgentExecutor > 10:chain:RunnableSequence > 11:chain:RunnableAssign<agent_scratchpad> > 12:chain:RunnableParallel<agent_scratchpad>] Entering Chain run with input:
# {
#   "input": ""
# }
# [chain/start] [1:chain:AgentExecutor > 10:chain:RunnableSequence > 11:chain:RunnableAssign<agent_scratchpad> > 12:chain:RunnableParallel<agent_scratchpad> > 13:chain:RunnableLambda] Entering Chain run with input:
# {
#   "input": ""
# }
# [chain/end] [1:chain:AgentExecutor > 10:chain:RunnableSequence > 11:chain:RunnableAssign<agent_scratchpad> > 12:chain:RunnableParallel<agent_scratchpad> > 13:chain:RunnableLambda] s] Exiting Chain run with output:
# [outputs]
# [chain/end] [1:chain:AgentExecutor > 10:chain:RunnableSequence > 11:chain:RunnableAssign<agent_scratchpad> > 12:chain:RunnableParallel<agent_scratchpad>] s] Exiting Chain run with output:
# [outputs]
# [chain/end] [1:chain:AgentExecutor > 10:chain:RunnableSequence > 11:chain:RunnableAssign<agent_scratchpad>] s] Exiting Chain run with output:
# [outputs]
# [chain/start] [1:chain:AgentExecutor > 10:chain:RunnableSequence > 14:prompt:ChatPromptTemplate] Entering Prompt run with input:
# [inputs]
# [chain/end] [1:chain:AgentExecutor > 10:chain:RunnableSequence > 14:prompt:ChatPromptTemplate] s] Exiting Prompt run with output:
# [outputs]
# [llm/start] [1:chain:AgentExecutor > 10:chain:RunnableSequence > 15:llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are a helpful assistant\nHuman: Task: Google search for James Phoenix's age. \n        Then square it.\nAI: {'arguments': '{\"__arg1\":\"James Phoenix age\"}', 'name': 'google_search'}\nFunction: James Phoenix is 31 years old."
#   ]
# }
# [llm/end] [1:chain:AgentExecutor > 10:chain:RunnableSequence > 15:llm:ChatOpenAI] s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "",
#         "generation_info": {
#           "finish_reason": "function_call"
#         },
#         "type": "ChatGenerationChunk",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessageChunk"
#           ],
#           "kwargs": {
#             "content": "",
#             "example": false,
#             "additional_kwargs": {
#               "function_call": {
#                 "arguments": "{\"__arg1\":\"31^2\"}",
#                 "name": "Calculator"
#               }
#             },
#             "tool_call_chunks": [],
#             "response_metadata": {
#               "finish_reason": "function_call"
#             },
#             "id": "run-d5e89be3-3663-42aa-a6dd-b2917f725f34",
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [chain/start] [1:chain:AgentExecutor > 10:chain:RunnableSequence > 16:parser:OpenAIFunctionsAgentOutputParser] Entering Parser run with input:
# [inputs]
# [chain/end] [1:chain:AgentExecutor > 10:chain:RunnableSequence > 16:parser:OpenAIFunctionsAgentOutputParser] s] Exiting Parser run with output:
# [outputs]
# [chain/end] [1:chain:AgentExecutor > 10:chain:RunnableSequence] s] Exiting Chain run with output:
# [outputs]
# [tool/start] [1:chain:AgentExecutor > 17:tool:Calculator] Entering Tool run with input:
# "31^2"
# [chain/start] [1:chain:AgentExecutor > 17:tool:Calculator > 18:chain:LLMMathChain] Entering Chain run with input:
# {
#   "question": "31^2"
# }
# [chain/start] [1:chain:AgentExecutor > 17:tool:Calculator > 18:chain:LLMMathChain > 19:chain:LLMChain] Entering Chain run with input:
# {
#   "question": "31^2",
#   "stop": [
#     "```output"
#   ]
# }
# [llm/start] [1:chain:AgentExecutor > 17:tool:Calculator > 18:chain:LLMMathChain > 19:chain:LLMChain > 20:llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Translate a math problem into a expression that can be executed using Python's numexpr library. Use the output of running this code to answer the question.\n\nQuestion: ${Question with math problem.}\n```text\n${single line mathematical expression that solves the problem}\n```\n...numexpr.evaluate(text)...\n```output\n${Output of running the code}\n```\nAnswer: ${Answer}\n\nBegin.\n\nQuestion: What is 37593 * 67?\n```text\n37593 * 67\n```\n...numexpr.evaluate(\"37593 * 67\")...\n```output\n2518731\n```\nAnswer: 2518731\n\nQuestion: 37593^(1/5)\n```text\n37593**(1/5)\n```\n...numexpr.evaluate(\"37593**(1/5)\")...\n```output\n8.222831614237718\n```\nAnswer: 8.222831614237718\n\nQuestion: 31^2"
#   ]
# }
# [llm/end] [1:chain:AgentExecutor > 17:tool:Calculator > 18:chain:LLMMathChain > 19:chain:LLMChain > 20:llm:ChatOpenAI] s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "```text\n31**2\n```\n...numexpr.evaluate(\"31**2\")...\n",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "```text\n31**2\n```\n...numexpr.evaluate(\"31**2\")...\n",
#             "additional_kwargs": {},
#             "name": null,
#             "id": "run-03a333c7-a257-484a-8810-8ce97fad157f-0",
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "completion_tokens": 21,
#       "prompt_tokens": 203,
#       "total_tokens": 224,
#       "prompt_tokens_details": {
#         "cached_tokens": 0,
#         "audio_tokens": 0
#       },
#       "completion_tokens_details": {
#         "reasoning_tokens": 0,
#         "audio_tokens": 0,
#         "accepted_prediction_tokens": 0,
#         "rejected_prediction_tokens": 0
#       }
#     },
#     "model_name": "gpt-3.5-turbo",
#     "system_fingerprint": null
#   },
#   "run": null
# }
# [chain/end] [1:chain:AgentExecutor > 17:tool:Calculator > 18:chain:LLMMathChain > 19:chain:LLMChain] s] Exiting Chain run with output:
# {
#   "text": "```text\n31**2\n```\n...numexpr.evaluate(\"31**2\")...\n"
# }
# [chain/end] [1:chain:AgentExecutor > 17:tool:Calculator > 18:chain:LLMMathChain] s] Exiting Chain run with output:
# {
#   "answer": "Answer: 961"
# }
# [tool/end] [1:chain:AgentExecutor > 17:tool:Calculator] s] Exiting Tool run with output:
# "Answer: 961"
# [chain/start] [1:chain:AgentExecutor > 21:chain:RunnableSequence] Entering Chain run with input:
# {
#   "input": ""
# }
# [chain/start] [1:chain:AgentExecutor > 21:chain:RunnableSequence > 22:chain:RunnableAssign<agent_scratchpad>] Entering Chain run with input:
# {
#   "input": ""
# }
# [chain/start] [1:chain:AgentExecutor > 21:chain:RunnableSequence > 22:chain:RunnableAssign<agent_scratchpad> > 23:chain:RunnableParallel<agent_scratchpad>] Entering Chain run with input:
# {
#   "input": ""
# }
# [chain/start] [1:chain:AgentExecutor > 21:chain:RunnableSequence > 22:chain:RunnableAssign<agent_scratchpad> > 23:chain:RunnableParallel<agent_scratchpad> > 24:chain:RunnableLambda] Entering Chain run with input:
# {
#   "input": ""
# }
# [chain/end] [1:chain:AgentExecutor > 21:chain:RunnableSequence > 22:chain:RunnableAssign<agent_scratchpad> > 23:chain:RunnableParallel<agent_scratchpad> > 24:chain:RunnableLambda] s] Exiting Chain run with output:
# [outputs]
# [chain/end] [1:chain:AgentExecutor > 21:chain:RunnableSequence > 22:chain:RunnableAssign<agent_scratchpad> > 23:chain:RunnableParallel<agent_scratchpad>] s] Exiting Chain run with output:
# [outputs]
# [chain/end] [1:chain:AgentExecutor > 21:chain:RunnableSequence > 22:chain:RunnableAssign<agent_scratchpad>] s] Exiting Chain run with output:
# [outputs]
# [chain/start] [1:chain:AgentExecutor > 21:chain:RunnableSequence > 25:prompt:ChatPromptTemplate] Entering Prompt run with input:
# [inputs]
# [chain/end] [1:chain:AgentExecutor > 21:chain:RunnableSequence > 25:prompt:ChatPromptTemplate] s] Exiting Prompt run with output:
# [outputs]
# [llm/start] [1:chain:AgentExecutor > 21:chain:RunnableSequence > 26:llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are a helpful assistant\nHuman: Task: Google search for James Phoenix's age. \n        Then square it.\nAI: {'arguments': '{\"__arg1\":\"James Phoenix age\"}', 'name': 'google_search'}\nFunction: James Phoenix is 31 years old.\nAI: {'arguments': '{\"__arg1\":\"31^2\"}', 'name': 'Calculator'}\nFunction: Answer: 961"
#   ]
# }
# [llm/end] [1:chain:AgentExecutor > 21:chain:RunnableSequence > 26:llm:ChatOpenAI] [1.11s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "James Phoenix is 31 years old. \nThe square of his age is 961.",
#         "generation_info": {
#           "finish_reason": "stop"
#         },
#         "type": "ChatGenerationChunk",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessageChunk"
#           ],
#           "kwargs": {
#             "content": "James Phoenix is 31 years old. \nThe square of his age is 961.",
#             "example": false,
#             "additional_kwargs": {},
#             "tool_call_chunks": [],
#             "response_metadata": {
#               "finish_reason": "stop"
#             },
#             "id": "run-b432fa92-9a1a-4d18-a378-344d1ae1c4b0",
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [chain/start] [1:chain:AgentExecutor > 21:chain:RunnableSequence > 27:parser:OpenAIFunctionsAgentOutputParser] Entering Parser run with input:
# [inputs]
# [chain/end] [1:chain:AgentExecutor > 21:chain:RunnableSequence > 27:parser:OpenAIFunctionsAgentOutputParser] s] Exiting Parser run with output:
# [outputs]
# [chain/end] [1:chain:AgentExecutor > 21:chain:RunnableSequence] [1.11s] Exiting Chain run with output:
# [outputs]
# [chain/end] [1:chain:AgentExecutor] [3.42s] Exiting Chain run with output:
# {
#   "output": "James Phoenix is 31 years old. \nThe square of his age is 961."
# }
# {'input': "Task: Google search for James Phoenix's age. \n        Then square it.", 'output': 'James Phoenix is 31 years old. \nThe square of his age is 961.'}
